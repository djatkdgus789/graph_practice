# %%
# Analysis of Large-Scale Multi-Tenant GPU Clusters
# for DNN Training Workloads 
# == Fig2 ==

from matplotlib import pyplot as plt
import matplotlib.ticker as ticker

plt.xlabel('Time(min)')
plt.ylabel('CDF')
plt.xscale('log')

cdf = [10**-1, 10**0, 10**1, 10**2, 10**3, 10**4, 10**5]
gpu1 =   [0, 8, 23, 85, 95, 99 ,100]
gpu2_4 = [0, 38, 50, 60, 72, 98, 100]
gpu5_8 = [0, 0, 20, 30, 60, 95, 100]
gpu8_ = [0, 7, 22, 40, 60, 99, 100]

# plt.xticks([10**-1, 10**0, 10**1, 10**2, 10**3, 10**4])
plt.plot(cdf, gpu1, 'g-', label='1 GPU')
plt.plot(cdf, gpu2_4, 'b-.', label='2-4 GPU')
plt.plot(cdf, gpu5_8, 'r--', label='5-8 GPU')
plt.plot(cdf, gpu8_, 'm--', label='>8 GPU')
plt.xticks(rotation=45)

plt.legend(loc='lower right')
plt.grid(linestyle='--')
plt.show()

# %%
# Analysis of Large-Scale Multi-Tenant GPU Clusters
# for DNN Training Workloads 
# == Fig4 ==

from matplotlib import pyplot as plt
import matplotlib.ticker as ticker

plt.xlabel('Time (min)')
plt.ylabel('Num. Servers')
plt.xscale('log')

time = [10**-1, 10**0, 10**2, 10**3]
gpu5_8 = [0, 4, 7, 4]
gpu8_  = [0, 16, 7, 4]

plt.scatter(server, gpu5_8,c='black', marker='+',label='5-8 GPU' )
plt.scatter(server, gpu8_, facecolors='none', edgecolors='r', marker='o',label='>8 GPU' )
plt.legend(loc='upper right')

plt.show()

# %%
# Analysis of Large-Scale Multi-Tenant GPU Clusters
# for DNN Training Workloads 
# == Fig8 ==

from matplotlib import pyplot as plt
import matplotlib.ticker as ticker

plt.xlabel('Fraction of Epochs')
plt.ylabel('CDF')
plt.ylim([0,100])

cdf1 = [0, 1, 1, 16, 16, 16,100]
lowest_loss = [0,0.2,0.3, 0.3,0.4,1.0,1.0]

cdf2 = [0, 0, 0, 60, 80, 100]
within_01_of_lowest_low = []

plt.plot(lowest_loss, cdf1, '-', label='Lowest loss')


plt.show()
